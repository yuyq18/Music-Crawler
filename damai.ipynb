# %%
import pandas as pd
import requests
import os
import time
from time import sleep
import random
import json
import hashlib

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299',
    'Cookie': 'cna=Kvm0HlkLLxMCAbetkdHo8vj+; xlly_s=1; XSRF-TOKEN=65e91fd3-9574-4c58-a160-885d824a24e1; tfstk=fDJxtVmVf0EAXDhMhnGk7u2_zRno-KKVwE-QINb01ULJfenVjqJMwGLMym-DfqR9yhTK0G02IQE9YULO_m7G5NLMfImoKvx20OW6X2DnKJ429RvA5PX6ugE8Q20nKYcbVO3x-C4fvNWRbasfc-_j2asGjOwbhF_5NMs3lO6653iRfiFbc-_bVus6zp2P7f_3BLfLmkjs4Ze_CLHNMwKbsRw6eiCAtn_JmnvRDsQCZ67hLpKBcpS9QDNOWHRXog8tp4BWHEpfwOHTUtxpNECJMVeRaQteC_drJW-ecEdCOKM-4_p2xt_JQcyNlIx6I1pjRlbX3EvRTdzxrNAHqK1JR42J71dXOt9tJYszVpvdEK4hJGVj20Fa_sskzbI-0U4Et4IR-0Yb_558TgQn2jNa_ssP2wmlU5PNwW5..; isg=BMnJICw6y0MBObci0MT-6S7Y2PMjFr1IdbFhWms-RbDvsunEs2bNGLfg9RYEvFWA',
    'X-Xsrf-Token': '7d065ac9-b924-4c14-869a-ab599b571244',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9,zh;q=0.8,zh-CN;q=0.7',
    'Bx-V': '2.5.0',
    'Referer': 'https://search.damai.cn/search.htm?spm=a2oeg.home.category.ditem_0.591b23e1HxE6Vj&ctl=%E6%BC%94%E5%94%B1%E4%BC%9A&order=1&cty=%E6%88%90%E9%83%BD',
    'Sec-Ch-Ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "macOS",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
}

# %%
url = 'https://search.damai.cn/searchajax.html'

# %%
ids_list = []
meta_df = pd.DataFrame(columns=['currentPage', 'maxPage', 'maxTotalResults', 'nextPage', 'onePageSize', 'previousPage', 'totalPage', 'totalResults'])
details_df = pd.DataFrame(columns=['activityTags', 'actors', 'business', 'categoryid', 'categoryname', 'cityid', 'cityname', 'couponTags', 'description', 'id', 'imgurl', 'isAtmospheric', 'iseticket', 'isgeneralagent', 'issuperticket', 'isxuanzuo', 'name', 'nameNoHtml', 'price', 'price_str', 'pricehigh', 'privilegeTags', 'projectid', 'promotionTags', 'showstatus', 'showtag', 'showtime', 'sitestatus', 'subcategoryid', 'subcategoryname', 'subhead', 'venue', 'venuecity', 'venueid', 'verticalPic'])

# %%
params = {
    'keyword': '',
    'cty': '',
    'ctl': '演唱会',
    'sctl': '',
    'tsg': '0',
    'st': '',
    'et': '',
    'order': '1',
    'pageSize': '30',
    'currPage': '1',
    'tn': '',
}

# %%
# 爬取每一页
totalPage = 66

for i in range(1, totalPage+1):
    print(f'正在爬取第{i}页')
    params['currPage'] = str(i)
    response = requests.get(url, headers=headers, params=params)
    json_data = response.json()

    curr_page_id_list = json_data['ids'].split(',')
    ids_list.extend(curr_page_id_list)

    new_meta_row = {}
    for col_ in meta_df.columns:
        new_meta_row[col_] = json_data['pageData'][col_]
    meta_df = pd.concat([meta_df, pd.DataFrame([new_meta_row])], ignore_index=True)
        
    for detail_data in json_data['pageData']['resultData']:
        new_detail_row = {}
        for col_ in details_df.columns:
            new_detail_row[col_] = detail_data[col_]
        details_df = pd.concat([details_df, pd.DataFrame([new_detail_row])], ignore_index=True)
    sleep(random.randint(1, 3))
# Out:
# 正在爬取第1页
# /tmp/ipykernel_4075520/3304584456.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   details_df = pd.concat([details_df, pd.DataFrame([new_detail_row])], ignore_index=True)
# 正在爬取第2页
# 正在爬取第3页
# 正在爬取第4页
# 正在爬取第5页
# 正在爬取第6页
# 正在爬取第7页
# 正在爬取第8页
# 正在爬取第9页
# 正在爬取第10页
# 正在爬取第11页
# 正在爬取第12页
# 正在爬取第13页
# 正在爬取第14页
# 正在爬取第15页
# 正在爬取第16页
# 正在爬取第17页
# 正在爬取第18页
# 正在爬取第19页
# 正在爬取第20页
# 正在爬取第21页
# 正在爬取第22页
# 正在爬取第23页
# 正在爬取第24页
# 正在爬取第25页
# 正在爬取第26页
# 正在爬取第27页
# 正在爬取第28页
# 正在爬取第29页
# 正在爬取第30页
# 正在爬取第31页
# 正在爬取第32页
# 正在爬取第33页
# 正在爬取第34页
# 正在爬取第35页
# 正在爬取第36页
# 正在爬取第37页
# 正在爬取第38页
# 正在爬取第39页
# 正在爬取第40页
# 正在爬取第41页
# 正在爬取第42页
# 正在爬取第43页
# 正在爬取第44页
# 正在爬取第45页
# 正在爬取第46页
# 正在爬取第47页
# 正在爬取第48页
# 正在爬取第49页
# 正在爬取第50页
# 正在爬取第51页
# 正在爬取第52页
# 正在爬取第53页
# 正在爬取第54页
# 正在爬取第55页
# 正在爬取第56页
# 正在爬取第57页
# 正在爬取第58页
# 正在爬取第59页
# 正在爬取第60页
# 正在爬取第61页
# 正在爬取第62页
# 正在爬取第63页
# 正在爬取第64页
# 正在爬取第65页
# 正在爬取第66页

# %%
meta_df
# Out:
#    currentPage maxPage maxTotalResults nextPage onePageSize previousPage  \
# 0            1     160            1980        2          30            1
# 1            2     160            1980        3          30            1
# 2            3     160            1980        4          30            2
# 3            4     160            1980        5          30            3
# 4            5     160            1980        6          30            4
# ..         ...     ...             ...      ...         ...          ...
# 61          62     160            1980       63          30           61
# 62          63     160            1980       64          30           62
# 63          64     160            1980       65          30           63
# 64          65     160            1980       66          30           64
# 65          66     160            1980       66          30           65
#
#    totalPage totalResults
# 0         66         1980
# 1         66         1980
# 2         66         1980
# 3         66         1980
# 4         66         1980
# ..       ...          ...
# 61        66         1980
# 62        66         1980
# 63        66         1980
# 64        66         1980
# 65        66         1980
#
# [66 rows x 8 columns]

# %%
details_df
# Out:
#      activityTags                                             actors business  \
# 0              []  艺人：毛不易、赵雷、蒲熠星、八三夭、黄子弘凡、黄誉博、夏日入侵企画、deca joins、郑...        0
# 1              []  艺人：痛仰乐队、二手玫瑰、凤凰传奇、林宥嘉、陈绮贞、陈楚生、郭顶、梅卡德尔、文雀乐队、周柏豪...        0
# 2              []    艺人：毛不易、艾热、TANK吕建忠、威尔Will.T、霓虹花园、石岩、布瑞吉、vava、派克特        0
# 3              []  艺人：痛仰乐队、二手玫瑰、房东的猫、许巍、老狼、棱镜乐队、万能青年旅店、银河快递、野肆乐队、...        0
# 4              []  艺人：赵雷、郑润泽、宝石GEM、黄誉博、王贰浪、队长YoungCaptain、vava、威尔...        0
# ...           ...                                                ...      ...
# 1975           []                                                           0
# 1976           []                                          艺人：曾涵江CUP        0
# 1977           []                                                           0
# 1978           []                                             艺人：林志炫        0
# 1979           []                                                           0
#
#      categoryid categoryname cityid cityname couponTags  \
# 0             1          演唱会   1052       无锡         []
# 1             1          演唱会    702       长沙         []
# 2             1          演唱会   2017       东营         []
# 3             1          演唱会   3014       长治         []
# 4             1          演唱会   2536       蚌埠         []
# ...         ...          ...    ...      ...        ...
# 1975          1          演唱会    872       上海         []
# 1976          1          演唱会    872       上海         []
# 1977          1          演唱会    872       上海         []
# 1978          1          演唱会    872       上海         []
# 1979          1          演唱会    451       三明         []
#
#                                             description                id  \
# 0     艺人：毛不易、赵雷、蒲熠星、八三夭、黄子弘凡、黄誉博、夏日入侵企画、deca joins、郑...  1_1_794250306538
# 1     艺人：痛仰乐队、二手玫瑰、凤凰传奇、林宥嘉、陈绮贞、陈楚生、郭顶、梅卡德尔、文雀乐队、周柏豪...  1_1_787238251934
# 2       艺人：毛不易、艾热、TANK吕建忠、威尔Will.T、霓虹花园、石岩、布瑞吉、vava、派克特  1_1_793106276209
# 3     艺人：痛仰乐队、二手玫瑰、房东的猫、许巍、老狼、棱镜乐队、万能青年旅店、银河快递、野肆乐队、...  1_1_789691550926
# 4     艺人：赵雷、郑润泽、宝石GEM、黄誉博、王贰浪、队长YoungCaptain、vava、威尔...  1_1_789343792733
# ...                                                 ...               ...
# 1975                                                        1_1_220038018
# 1976                                          艺人：曾涵江CUP     1_1_219548071
# 1977                                                        1_1_220277030
# 1978                                             艺人：林志炫     1_1_219910020
# 1979                                                        1_1_220402025
#
#       ... showtag               showtime sitestatus subcategoryid  \
# 0     ...               2024.05.18-05.19          3            12
# 1     ...               2024.06.14-06.16          3            12
# 2     ...               2024.06.22-06.23          3            12
# 3     ...               2024.07.13-07.14          3            12
# 4     ...               2024.05.18-05.19          3            12
# ...   ...     ...                    ...        ...           ...
# 1975  ...                  2024.06.01 周六          3            13
# 1976  ...                           时间待定          3            12
# 1977  ...                  2024.07.20 周六          3            13
# 1978  ...                  2024.07.20 周六          3            13
# 1979  ...          2024.07.05~2024.07.06          3            12
#
#      subcategoryname subhead         venue venuecity  venueid  \
# 0                音乐节          无锡-融创乐园旁边大草坪        无锡  6473054
# 1                音乐节          长沙国际会展中心 西广场        长沙  2148014
# 2                音乐节            东营揽翠湖旅游度假区        东营  2785008
# 3                音乐节                 欢乐太行谷        长治  3179010
# 4                音乐节            蚌埠市体育中心体育场        蚌埠  1652003
# ...              ...     ...           ...       ...      ...
# 1975              其他            浦发银行东方体育中心        上海        0
# 1976             音乐节             上海玛雅海滩水公园        上海        0
# 1977              其他            浦发银行东方体育中心        上海        0
# 1978              其他           梅赛德斯-奔驰文化中心        上海        0
# 1979             音乐节           沙县金沙园美食音乐广场        三明        0
#
#                                             verticalPic
# 0     https://img.alicdn.com/bao/uploaded/https://im...
# 1     https://img.alicdn.com/bao/uploaded/https://im...
# 2     https://img.alicdn.com/bao/uploaded/https://im...
# 3     https://img.alicdn.com/bao/uploaded/https://im...
# 4     https://img.alicdn.com/bao/uploaded/https://im...
# ...                                                 ...
# 1975  http://damai-mx-partner-admin.oss-cn-beijing.a...
# 1976  http://damai-mx-partner-admin.oss-cn-beijing.a...
# 1977  http://damai-mx-partner-admin.oss-cn-beijing.a...
# 1978  http://damai-mx-partner-admin.oss-cn-beijing.a...
# 1979  http://damai-mx-partner-admin.oss-cn-beijing.a...
#
# [1980 rows x 35 columns]

# %%
len(ids_list)
# Out:
# 1980

# %%
# save to csv file
meta_df.to_csv('damai-music/meta/meta-20240513.csv', index=False)
details_df.to_csv('damai-music/meta/details-20240513.csv', index=False)

# %% [markdown]
# # 爬取每场演出的 Details

# %%
# read csv file and get id_list
details_df = pd.read_csv('damai-music/meta/details-20240513.csv')
id_list = list(details_df['projectid'])
len(id_list)
# Out:
# 1980

# %%
details_df['projectid'].nunique()
# Out:
# 1979

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299',
    'Cookie': 'cna=Kvm0HlkLLxMCAbetkdHo8vj+; xlly_s=1; _bl_uid=melILwt91pauUj7F5k4g1L3wFs7b; mtop_partitioned_detect=1; _m_h5_tk=0024383cda2fbdc691aba4c461694487_1715614040098; _m_h5_tk_enc=e8a6f1c7d05a6cacf77daf9fb88df733; tfstk=fORiMtN0LMZWBcUxjBfsTEqKgLMd1l1fqnFADsIqLMSCBtojCIfDXMdOH1STonYylGSAH1H0in8P3nIvWq46t3VY6cM6uSfAg0n-wbLsCs1q20S-9vS1leS4x7_0KF1fgDULgYhk53Avo1DGg2fFoZFVgiyZ-M7cY574_ZrE-ZsF0sWVgkrFrNra7GP2r8idXGSXT4KahQrSSVAh7msySMbCRBbGIgWFxS89tNXG4FR_R8VOoLRlC3oLBGJkF3bJXXPMqF-MUTRaYDfXJLxcrCuzEix68CBe_qe5Rs9wU1Rmql8BjhO6UFoLKwveWBXpa0VcCp-6FtAxvb19eUdfUClgVMB5o3fwKDPM4gWuL8ukeS_EkBybhO7C-gZBUKtGJn17p203UNXNRNPK-22byO7C-g3n-85AQw_a9; isg=BHh4lwgfapnkO4ZxafM_KmcHSSAK4dxrbP4wabLplbNmzRi3WvRn-vz_g8X9hpRD',
    'X-Xsrf-Token': '7d065ac9-b924-4c14-869a-ab599b571244',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9,zh;q=0.8,zh-CN;q=0.7',
    'Bx-V': '2.5.0',
    'Referer': 'https://detail.damai.cn/item.htm?spm=a2oeg.search_category.0.0.5f724d15IPEWYe&id=789240991916&clicktitle=%E9%82%93%E7%B4%AB%E6%A3%8B%201%20AM%20GLORIA%20%E4%B8%96%E7%95%8C%E5%B7%A1%E5%9B%9E%E6%BC%94%E5%94%B1%E4%BC%9A-%E5%8D%97%E4%BA%AC%E7%AB%99',
    'Sec-Ch-Ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "macOS",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
}

_m_h5_tk='0024383cda2fbdc691aba4c461694487_1715614040098'

# %%
# url = 'https://mtop.damai.cn/h5/mtop.damai.item.detail.getdetail/1.0/'
url = 'https://mtop.damai.cn/h5/mtop.damai.item.projectdetail.projectid.get/1.1/'

# %%
# params 示例
# params = {
#     'jsv': '2.7.2',
#     'appKey': '12574478',
#     't': '1715426122728',
#     'sign': '61c0dd04778bed4ea7d64fa94447b527',
#     'api': 'mtop.damai.item.detail.getdetail',
#     'v': '1.0',
#     'H5Request': 'true',
#     'type': 'json',
#     'timeout': '10000',
#     'dataType': 'json',
#     'valueType': 'string',
#     'forceAntiCreep': 'true',
#     'AntiCreep': 'true',
#     'useH5': 'true',
#     'data': {
#         "itemId":"670401840202",
#         "platform":"8",
#         "comboChannel":"2",
#         "dmChannel":"damai@damaih5_h5"
#     },
# }
params = {
    'jsv': '2.7.2',
    'appKey': '12574478',
    't': '1715604863115',
    'requestStart': '1715604036185',
    'sign': '61c0dd04778bed4ea7d64fa94447b527',
    'api': 'mtop.damai.item.projectdetail.projectid.get',
    'v': '1.1',
    'H5Request': 'true',
    'type': 'originaljsonp',
    'dataType': 'jsonp',
    'valueType': 'original',
    'AntiCreep': 'true',
    'AntiFlood': 'true',
    'callback': 'mtopjsonp1',
    'data': {
        "projectId":"219548071",
        "dmChannel":"damai@damaih5_h5"
    }
}

# %%
def get_sign(ts, data, _m_h5_tk=None):
    if _m_h5_tk:
        token = _m_h5_tk.split('_')[0]
    else:
        token = "undefined"
    text = f'{token}&{ts}&12574478&{data}'
    md5 = hashlib.md5()
    md5.update(text.encode('utf-8'))
    result = md5.hexdigest()
    return result

# %%
import os
exist_files_1 = os.listdir('./damai-music/docs')
exist_ids = [int(file.split('.')[0]) for file in exist_files_1]
print(len(exist_ids))
# Out:
# 1979

# %%
problem_ids = []

# %%
id_list = [220288009,
 220252010,
 219811054,
 220387016,
 220347010,
 219781078,
 217620011,
 220332010,
 220277030,
 219910020,
 220038018,
 220332016,
 219548071,
 220402025,
 220273021,
 220330015,
 220350014,
 220235008,
 215140016
]

# %%
exist_ids = []

# %%
# 修改参数 t sign data itemId

for (i, id) in enumerate(id_list):
    if id in exist_ids:
        # print(f'已经爬取过: {i} - {id}')
        continue
    print(f'正在爬取第{i}个id')
    # params['data'] = {
    #     "itemId":str(id),
    #     "platform":"8",
    #     "comboChannel":"2",
    #     "dmChannel":"damai@damaih5_h5"
    # }
    params['data'] = {
        "projectId":str(id),
        "dmChannel":"damai@damaih5_h5"
    }

    params['t'] = int(time.time())
    params['requestStart'] = params['t']-1
    json_str = json.dumps(params['data'], ensure_ascii=False)
    json_str = json_str.replace(' ', '')
    params['data'] = json_str
    params['sign']= get_sign(ts = params['t'],
                # data = "{\"itemId\":\"670401840202\",\"platform\":\"8\",\"comboChannel\":\"2\",\"dmChannel\":\"damai@damaih5_h5\"}",
                data = json_str,
                _m_h5_tk=_m_h5_tk,
                )
    r = requests.get(url, headers=headers, params=params)
    # json_r = r.json()
    json_r = json.loads(r.text.replace(' mtopjsonp1(','').replace(')',''))
    if 'data' in json_r:
        if 'legacy' in json_r['data']:
            json_legacy = json.loads(json_r['data']['legacy'])
            json_docs = {}
            for col_ in details_df.columns:
                if col_ not in json_legacy:
                    json_docs[col_] = str(details_df[details_df['projectid']==id][col_].values[0])
            
            json_docs.update(json_legacy)
            with open(f'damai-music/docs/{id}.json', 'w') as f:
                json.dump(json_docs, f, indent=4, ensure_ascii=False)
        elif not isinstance(json_r['data'], str):
            json_data = json_r['data']
            json_docs = {}
            for col_ in details_df.columns:
                json_docs[col_] = str(details_df[details_df['projectid']==id][col_].values[0])
            
            json_docs.update(json_data)
            with open(f'damai-music/docs2/{id}.json', 'w') as f:
                json.dump(json_docs, f, indent=4, ensure_ascii=False)

            # with open(f'damai-2/{id}.json', 'w') as f:
            #     json.dump(json_r['data'], f, indent=4)
            # print(json_r)
            # print(f'====================解析失败: {i} - {id}')
            # problem_ids.append(id)
            # break
        else:
            print(f'====================解析gg: {i} - {id}')
            # problem_ids.append(id)
            print(json_r)
    else:
        print(f'====================请求失败: {i} - {id}')
        # problem_ids.append(id)
# Out:
# 正在爬取第0个id
# 正在爬取第1个id
# 正在爬取第2个id
# 正在爬取第3个id
# 正在爬取第4个id
# 正在爬取第5个id
# 正在爬取第6个id
# 正在爬取第7个id
# 正在爬取第8个id
# 正在爬取第9个id
# 正在爬取第10个id
# 正在爬取第11个id
# 正在爬取第12个id
# 正在爬取第13个id
# 正在爬取第14个id
# 正在爬取第15个id
# 正在爬取第16个id
# 正在爬取第17个id
# 正在爬取第18个id

# %%
r_text = r.text.replace(' mtopjsonp1(','').replace(')','')
r_json = json.loads(r_text)
r_json['data']
# Out:
# {'item': {'buyBtnStatus': 1, 'buyBtnText': '预约抢票', 'buyBtnTip': '开抢前第一时间提醒你'},
#  'staticData': {'fissionSharingIcon': 'https://gw.alicdn.com/tfs/TB10ibEpkL0gK0jSZFAXXcA9pXa-186-75.png',
#   'itemBase': {'cityId': 310100,
#    'cityName': '上海',
#    'itemId': 220288009,
#    'itemIdForH5': '795371870553',
#    'itemName': '【上海】2024周柏豪「奔赴」世界巡回演唱会-上海站',
#    'itemPics': {'itemPicList': [{'picUrl': 'http://damai-mx-partner-admin.oss-cn-beijing.aliyuncs.com/f802ac6a-2db6-4049-96ca-1810c0322d6e.jpg'}]},
#    'showTime': '2024.06.15 周六'},
#   'itemExtendInfo': {'itemDescTitle': '项目详情',
#    'itemExtend': '<div style="clear: both;"><span style="font-weight: bold;">2024周柏豪「奔赴」世界巡回演唱会-上海站</span><div style="clear: both;"><span style="font-weight: bold;">演出日期：预计6月15日<br></span></div><div style="clear: both;"><span style="font-weight: bold;">演出地点：浦发银行东方体育中心<br></span></div><div style="clear: both;"><br></div><div style="clear: both;">人生<br></div><div style="clear: both;">是一次充满不确定的远行<br></div><div style="clear: both;">前方虽有迷雾<br></div><div style="clear: both;">更有扑面的光<br></div><div style="clear: both;">我们愿为之迈开脚步&nbsp;向此奔赴<br></div><div style="clear: both;"></div></div><div style="clear: both;"><img src="http://damai-mx-partner-admin.oss-cn-beijing.aliyuncs.com/5e4bc722-d898-468d-b022-5dbc9da882aa.JPG" style="vertical-align: bottom;"></div><div style="clear: both;"><div style="clear: both;"></div><div style="clear: both;">奔&nbsp;向期待已久的光<br></div><div style="clear: both;">赴&nbsp;一场七彩绚烂的梦<br></div><div style="clear: both;">2024周柏豪「奔赴」世界巡回演唱会<br></div><div style="clear: both;">耳机中的男歌手跨越山海，向你奔赴而来。<br></div><div style="clear: both;"></div></div><div style="clear: both;"><img src="http://damai-mx-partner-admin.oss-cn-beijing.aliyuncs.com/3e95a850-f4ac-49c6-8e30-38417569e23b.JPG" style="vertical-align: bottom;"></div><div style="clear: both;"><div style="clear: both;"></div><div style="clear: both;">奔赴主题的巡演着眼于柏豪在音乐上的新风格尝试，务求为观众呈现全新的音乐体验。<br></div><div style="clear: both;">这一轮的巡演已在各地陆续袭来，新的一年，柏豪将继续奔赴，去到更多非粤语城市与歌迷见面。<br></div><div style="clear: both;">2024年6月15日，他将再次来到上海举行个人演唱会。<br></div><div style="clear: both;">期待这次在现场的点点星海，共同完成这一次不负期待的双向奔赴。<br></div><div style="clear: both;"></div></div><div style="clear: both;"><img src="http://damai-mx-partner-admin.oss-cn-beijing.aliyuncs.com/adfd08e0-8802-449b-aa27-228e4ecb98fa.JPG" style="vertical-align: bottom;"></div><div style="clear: both;"><div style="clear: both;"></div><div style="clear: both;">【禁限带物品清单】<br></div><div style="clear: both;">对于现场观众所携带物品中的禁止和限制带入场物品现做详细说明如下：<br></div><div style="clear: both;">1.禁止携带旗帜、旗杆、自拍杆（包括任何伸缩旗帜及旗杆）。<br></div><div style="clear: both;">2.禁止携带横幅、条幅。<br></div><div style="clear: both;">3.禁止携带灯牌、灯幅等应援物品。<br></div><div style="clear: both;">4.禁止携带使用激光笔、投影设备。<br></div><div style="clear: both;">5.禁止携带打火机。<br></div><div style="clear: both;">6.禁止携带冷焰火。<br></div><div style="clear: both;">7.禁止管制刀具。<br></div><div style="clear: both;">8.禁止携带枪支弹药。<br></div><div style="clear: both;">9.禁止携带易燃易爆危险物品。<br></div><div style="clear: both;">10.禁止携带宠物。<br></div><div style="clear: both;">11.禁止携带高度酒精类饮品。<br></div><div style="clear: both;">12.禁止携带航拍器。<br></div><div style="clear: both;">13.禁止携带瓶装饮料。<br></div><div style="clear: both;">14.禁止携带使用长柄雨伞。<br></div><div style="clear: both;">15.禁止携带充气物（如气球，气棒等）。<br></div><span>16.禁止携带大件行李：尺寸超过50cmX36cm的行李箱禁止。（现场无寄存）<br></span></div>'},
#   'venue': {'distance': '',
#    'lat': 31.15753,
#    'lng': 121.479292,
#    'venueAddr': '上海市浦东新区耀体路701号',
#    'venueCityName': '上海市',
#    'venueId': 53332,
#    'venueName': '浦发银行东方体育中心'}}}

# %%
json_r['data']['desc']
# Out:
# {'introduce': '<html>\r\n<head>\r\n\r\n</head><body>\r\n<p><strong><img src="https://img.alicdn.com/imgextra/i3/2251059038/O1CN01tE2fBp2GdSaN5OQmp_!!2251059038.jpg"/></strong><strong>极光乐队延续和平与爱致敬BEYOND40周年巡回演唱会&ndash;宝鸡站 </strong></p>\r\n<p>演出时间：2024年5月18日19:30（周六）</p>\r\n<p>演出票价：80-120-180-280</p>\r\n<p>演出场馆：宝鸡大剧院</p>\r\n<p>取票地址：宝鸡市金台大道65号宝鸡大剧院票务中心</p>\r\n<p>取票方式：演出前1小时宝鸡大剧院票务中心自助机取票</p>\r\n<p><img src="https://img.alicdn.com/imgextra/i3/2251059038/O1CN01qo62OW2GdSaOgWBdZ_!!2251059038.jpg"/></p>\r\n<p><img src="https://img.alicdn.com/imgextra/i4/2251059038/O1CN01BlX0Jr2GdSaGeWBvn_!!2251059038.jpg"/></p>\r\n</body></html>',
#  'introduceTitle': '演出介绍'}

# %%
# debug 请求失败原因
# 775727800709

params['data'] = {
    "itemId":str(775727800709),
    "platform":"8",
    "comboChannel":"2",
    "dmChannel":"damai@damaih5_h5"
}

params['t'] = int(time.time())
json_str = json.dumps(params['data'], ensure_ascii=False)
json_str = json_str.replace(' ', '')
params['data'] = json_str
params['sign']= get_sign(ts = params['t'],
            # data = "{\"itemId\":\"670401840202\",\"platform\":\"8\",\"comboChannel\":\"2\",\"dmChannel\":\"damai@damaih5_h5\"}",
            data = json_str,
            _m_h5_tk=_m_h5_tk,
            )
r = requests.get(url, headers=headers, params=params)
json_r = r.json()
json_r
# if 'data' in json_r:
#     if 'legacy' in json_r['data']:
json_data = json_r['data']
with open(f'damai-test/{id}.json', 'w') as f:
    json.dump(json_data, f, indent=4)

# %%
json_r['data']
# Out:
# {'actionControl': {'degradeControl': {'comment': 'false',
#    'recommend': 'false'},
#   'hotProject': 'false'},
#  'buyButton': {'origin': '5', 'status': '207', 'text': '特惠购买'},
#  'desc': {'introduce': '<html>\r\n<head>\r\n\r\n</head><body>\r\n<p><img src="https://img.alicdn.com/imgextra/i1/2251059038/O1CN01xpgDFE2GdSaQesnOR_!!2251059038.png"/><img src="https://img.alicdn.com/imgextra/i1/2251059038/O1CN01AIB9Tb2GdSaTiTuBG_!!2251059038.png"/><img src="https://img.alicdn.com/imgextra/i4/2251059038/O1CN014I5OrP2GdSaWnNiva_!!2251059038.png"/><br/><br/><br/><br/>馨提示：演出节目及演员阵容以演出现场为准。</p>\r\n</body></html>',
#   'introduceTitle': '演出介绍'},
#  'ext': {'alipayLandingPageUrl': 'https://render.alipay.com/p/s/i',
#   'atomSplit': '1'},
#  'faqs': ['有座位图可以查看吗',
#   '我该怎么选座',
#   '我想要订票，怎么操作',
#   '演出时长大概是多少呢',
#   '入场时间是什么时候',
#   '儿童也是全票吗',
#   '我想了解退票规则',
#   '取票地址在哪里'],
#  'guide': {'brands': [{'bgPicUrl': 'https://img.alicdn.com/imgextra/i2/O1CN01uPMmU61NhIm2oSJvb_!!6000000001601-2-tps-1125-1260.png',
#     'desc': '',
#     'fansCount': '145870',
#     'fansCountStr': '14.6万',
#     'id': '549',
#     'label': '',
#     'name': '大笑喜剧',
#     'picUrl': 'https://img.alicdn.com/imgextra/i1/O1CN01nONqTD1xbBeSZXnw3_!!6000000006461-2-tps-300-300.png',
#     'tag': '品牌'}],
#   'ranking': {'id': '3154', 'name': '脱口秀高分榜', 'order': '2'},
#   'rating': {'commentTitle': '评分说明',
#    'commentUrl': 'https://t.damai.cn/yep/page/m/pingfen2023',
#    'contentLabelDOS': [{'labelId': '8356657648883957511-11',
#      'labelName': '爆笑亮点',
#      'labelType': '99'},
#     {'labelId': '4132265641623203105-11',
#      'labelName': '推荐推荐',
#      'labelType': '99'},
#     {'labelId': '1021226559958003842-11',
#      'labelName': '氛围很好',
#      'labelType': '99'},
#     {'labelId': '8277244642373825146-11',
#      'labelName': '座位视野',
#      'labelType': '99'},
#     {'labelId': '2272819976343676984-11',
#      'labelName': '演员很有梗',
#      'labelType': '99'},
#     {'labelId': '8552709640356584820-11',
#      'labelName': '下次还会来',
#      'labelType': '99'}],
#    'contentTags': [],
#    'desc': '大麦购票用户',
#    'name': '大麦评分',
#    'rating': '9.6',
#    'ratingNumDesc': '1151条',
#    'star': '9',
#    'starDesc': '极好',
#    'userRatingVOS': [{'content': '脱口秀是一种以幽默和讽刺为主要表现形式的表演艺术，它可以让人们在轻松愉快的氛围中思考和探讨各种话题。评价脱口秀可以从多个方面入手，比如表演者的口才、幽默程度、观点深度、与观众的互动等。当然，不同的人对脱口秀的评价可能会有所不同，这也取决于个人的喜好和文化背景\n❤️推荐理由\n很好\n🤣爆笑亮点\n很不错\n💺座位视野\n棒棒哒',
#      'contentId': '100006492146',
#      'userId': '481924697',
#      'userImg': 'https://perico.damai.cn/userheadphotosnew/2409623/481924697_1709869009061.jpg',
#      'userNick': '九里-中中中票!',
#      'userStar': '10.0'},
#     {'content': '第一次看线下演出，还是比较搞笑，轻松愉快，互动感强',
#      'contentId': '100006417309',
#      'userId': '246945278',
#      'userImg': 'https://perico.damai.cn/userheadphotosnew/1234726/246945278_1688623516482.jpg',
#      'userNick': '麦子50TEa',
#      'userStar': '10.0'},
#     {'content': '第好几次听现场的脱口秀的，现场的氛围真的还挺好的，其实也挺看现场观众配合的，最后的即兴真的太搞笑了，莫名一整个故事就连的很顺。',
#      'contentId': '100006382260',
#      'userId': '461314719',
#      'userImg': 'https://perico.damai.cn/userheadphotosnew/2306573/461314719_1697697591890.jpg',
#      'userNick': '麦子5SbMs',
#      'userStar': '10.0'}]},
#   'want': {'guideTipShareSubTitle': '记录心动演出，和好友结伴观演',
#    'guideTipShareTitle': '你的好友邀你标 [想看] 哦～',
#    'guideTipSubTitle': '在 [想看] 列表记录心动演出',
#    'guideTipTitle': '标 [想看] ，订阅最新优惠信息～',
#    'showWant': 'false',
#    'subFlag': 'false',
#    'thresholdNum': '10000',
#    'tipsSubTitle': '可购票时会及时通知你的～',
#    'tipsTitle': '已加入 [我的-想看想玩]',
#    'useLocalCache': 'false',
#    'wantNum': '9073',
#    'wantNumStr': '9073',
#    'wantNumSuffix': '人'}},
#  'item': {'catBgUrl': 'https://gw.alicdn.com/imgextra/i2/O1CN01Fsq2xk1mrG1bO9kO9_!!6000000005007-2-tps-1125-702.png',
#   'categoryId': '50019093',
#   'cityName': '杭州市',
#   'generalAgent': {'generalAgent': 'false', 'generalType': '1'},
#   'itemId': '775727800709',
#   'itemName': '【杭州】西湖脱口秀｜周一至周日｜综艺卡司｜吐槽爆笑大会｜开心互动｜【大笑喜剧】即兴之夜精品秀',
#   'itemPics': {'itemPicList': [{'picUrl': 'https://img.alicdn.com/imgextra/i2/2251059038/O1CN01o9JwtQ2GdSaVopxs2_!!2251059038.png'}]},
#   'itemType': '1',
#   'nationalStandardCityId': '330100',
#   'performSeatImages': [],
#   'projectId': '219752009',
#   'projectStatus': '1',
#   'realName': {'credentialNames': [], 'credentials': [], 'type': '3'},
#   'showDuration': '约90分钟（以现场为准）',
#   'showTime': '2024.05.12-06.02',
#   'tcCategoryId': '0302040600'},
#  'marketing': {'promotionDetail': {'promotionGroupList': [{'promotionGroupType': '1',
#      'promotionGroupTypeDesc': '票档优惠',
#      'promotionList': [{'promotionCategoryDetails': [{'displayContent': '7.9折，到手158（票档¥99x2）',
#          'skuName': '2人套票'},
#         {'displayContent': '9.2折，到手128（票档¥69x2）', 'skuName': '2人套票'}],
#        'promotionTag': '套票',
#        'promotionType': '3'}]}],
#    'promotionRemark': '说明：您选购优惠票档所对应的票品种类可能为套票、优惠票等类型，具体以您收到的票面信息标示为准。实际优惠情况以订单确认页为准。以上票档价格及优惠折扣基准价格均不含服务费。'},
#   'promotionList': {'generalPromotion': [{'prefix': '2人套票',
#      'suffix': '7.9折'}]}},
#  'performLimits': [{'performId': '213929378', 'singleLimitation': '6'},
#   {'performId': '213929379', 'singleLimitation': '6'},
#   {'performId': '213928261', 'singleLimitation': '6'},
#   {'performId': '213928262', 'singleLimitation': '6'},
#   {'performId': '213928263', 'singleLimitation': '6'},
#   {'performId': '213928264', 'singleLimitation': '6'},
#   {'performId': '213928265', 'singleLimitation': '6'},
#   {'performId': '213928266', 'singleLimitation': '6'},
#   {'performId': '213929380', 'singleLimitation': '6'},
#   {'performId': '213929381', 'singleLimitation': '6'},
#   {'performId': '213929382', 'singleLimitation': '6'},
#   {'performId': '213928267', 'singleLimitation': '6'},
#   {'performId': '213929383', 'singleLimitation': '6'},
#   {'performId': '213929384', 'singleLimitation': '6'},
#   {'performId': '213929385', 'singleLimitation': '6'},
#   {'performId': '213928268', 'singleLimitation': '6'},
#   {'performId': '214590010', 'singleLimitation': '6'},
#   {'performId': '214590011', 'singleLimitation': '6'},
#   {'performId': '214590012', 'singleLimitation': '6'},
#   {'performId': '214590013', 'singleLimitation': '6'},
#   {'performId': '214590014', 'singleLimitation': '6'},
#   {'performId': '214590015', 'singleLimitation': '6'},
#   {'performId': '214590016', 'singleLimitation': '6'},
#   {'performId': '214590017', 'singleLimitation': '6'},
#   {'performId': '214590018', 'singleLimitation': '6'},
#   {'performId': '214590019', 'singleLimitation': '6'},
#   {'performId': '214590020', 'singleLimitation': '6'},
#   {'performId': '214590021', 'singleLimitation': '6'},
#   {'performId': '214590022', 'singleLimitation': '6'},
#   {'performId': '214590023', 'singleLimitation': '6'},
#   {'performId': '214590024', 'singleLimitation': '6'},
#   {'performId': '214590025', 'singleLimitation': '6'},
#   {'performId': '214590026', 'singleLimitation': '6'},
#   {'performId': '214590027', 'singleLimitation': '6'},
#   {'performId': '214590028', 'singleLimitation': '6'},
#   {'performId': '214590029', 'singleLimitation': '6'},
#   {'performId': '214590030', 'singleLimitation': '6'},
#   {'performId': '214590031', 'singleLimitation': '6'},
#   {'performId': '214590032', 'singleLimitation': '6'},
#   {'performId': '214590033', 'singleLimitation': '6'},
#   {'performId': '214590034', 'singleLimitation': '6'},
#   {'performId': '214590035', 'singleLimitation': '6'}],
#  'price': {'range': '69-158'},
#  'purchaseGuide': {'purchaseGuideUrl': 'https://m.damai.cn/shows/pages/guide.html?transparentTitle=auto&itemId=775727800709',
#   'showFlag': 'false'},
#  'renderControl': {'hasServiceFee': 'false',
#   'isConcertType': 'false',
#   'showRealNamePopup': 'false'},
#  'serviceTips': {'importantNotes': [{'content': '每笔订单最多购买6张',
#     'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN01xHaeqo1zO1kHtIOEa_!!6000000006703-2-tps-144-144.png',
#     'title': '限购规则'},
#    {'content': '票品为有价票券，非普通商品，其背后承载的文化服务具有时效性，稀缺性等特征，不支持退换。',
#     'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN017tQHWJ1HHlETFHUP0_!!6000000000733-2-tps-144-144.png',
#     'title': '退票/换票规则'},
#    {'content': '支持多种票品验票后入场，如二维码电子票。',
#     'icon': 'https://gw.alicdn.com/imgextra/i1/O1CN01Q4zdmq1fUAkDGHxvo_!!6000000004009-2-tps-144-144.png',
#     'title': '入场方式说明'},
#    {'content': '儿童一律凭票入场',
#     'icon': 'https://gw.alicdn.com/imgextra/i1/O1CN018BKxF526fcGcgOjBP_!!6000000007689-2-tps-144-144.png',
#     'title': '儿童购票'},
#    {'content': '演出开始前，去【订单详情页】提交发票申请。我们会将电子发票发送至您的邮箱。',
#     'icon': 'https://gw.alicdn.com/imgextra/i2/O1CN01XnP8vt1l85L3ZSuW1_!!6000000004773-2-tps-144-144.png',
#     'title': '发票说明'},
#    {'content': '无需实名购票',
#     'icon': 'https://gw.alicdn.com/imgextra/i2/O1CN0176YBG91aNh407l1Jh_!!6000000003318-2-tps-144-144.png',
#     'title': '购票证件说明'},
#    {'content': '对于异常订购行为，大麦网有权在订单成立或者生效之后取消相应订单。异常订购行为包括但不限于以下情形：\n（1）通过同一ID订购超出限购张数的订单。\n（2）经合理判断认为非真实消费者的下单行为，包括但不限于通过批量相同或虚构的支付账号、收货地址（包括下单时填写及最终实际收货地址）、收件人、电话号码订购超出限购张数的订单。',
#     'icon': 'https://gw.alicdn.com/imgextra/i4/O1CN01unvwa31zkT9Y7bm7m_!!6000000006752-2-tps-144-144.png',
#     'title': '异常排单说明'},
#    {'content': '1.购买前请您提前规划好行程，做好相应准备，以免影响您的正常观演，感谢您的理解和配合。2.若演出受不可抗力影响延期或取消，大麦将对演出票订单按照项目官方通知方案进行处理，其他因观演发生的费用需由您自行承担。',
#     'icon': 'https://gw.alicdn.com/imgextra/i1/O1CN0133g7B81S91RyhPhBS_!!6000000002203-2-tps-144-144.png',
#     'title': '温馨提示'},
#    {'content': '约90分钟（以现场为准）',
#     'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN01Wa3Akl1hbA1Fg2zpP_!!6000000004295-2-tps-144-144.png',
#     'title': '演出时长'},
#    {'content': '请于演出前约30分钟入场',
#     'icon': 'https://gw.alicdn.com/imgextra/i2/O1CN01QHyDGA1rEOUPLb3WY_!!6000000005599-2-tps-144-144.png',
#     'title': '入场时间'},
#    {'content': '90分钟',
#     'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN01Wa3Akl1hbA1Fg2zpP_!!6000000004295-2-tps-144-144.png',
#     'title': '最低演出时长'},
#    {'content': '大笑喜剧',
#     'icon': 'https://gw.alicdn.com/imgextra/i4/O1CN01N7Icez1vcu9JtnH1e_!!6000000006194-2-tps-144-144.png',
#     'title': '主要演员'},
#    {'content': '由于安保和版权的原因，大多数演出、展览及比赛场所禁止携带食品、饮料、专业摄录设备、打火机等物品，请您注意现场工作人员和广播的提示，予以配合',
#     'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN01hOmBKs1l7AXuHwWV3_!!6000000004771-2-tps-144-144.png',
#     'title': '禁止携带物品'},
#    {'content': '无寄存处,无寄存处',
#     'icon': 'https://gw.alicdn.com/imgextra/i1/O1CN0191908w1a92OBNIwsi_!!6000000003286-2-tps-144-144.png',
#     'title': '寄存说明'},
#    {'content': '100',
#     'icon': 'https://gw.alicdn.com/imgextra/i1/O1CN01g1Fs6025i4mGCqzxa_!!6000000007559-2-tps-144-144.png',
#     'title': '大麦网初始开售时全场可售门票总张数'}],
#   'serviceTerm': [{'icon': 'https://gw.alicdn.com/imgextra/i4/O1CN01U4xvGO1qlzvKaYVze_!!6000000005537-2-tps-45-45.png',
#     'isSupport': 'false',
#     'renderType': '1',
#     'tagDesc': '票品为有价票券，非普通商品，其背后承载的文化服务具有时效性，稀缺性等特征，不支持退换。',
#     'tagName': '不支持退',
#     'tagType': '2'},
#    {'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN01W71UiF1LeRIVqb1Ci_!!6000000001324-2-tps-45-45.png',
#     'isSupport': 'true',
#     'renderType': '1',
#     'tagDesc': '通过票夹中的二维码验票入场',
#     'tagDescWithStyle': '通过票夹中的二维码验票入场',
#     'tagName': '电子票',
#     'tagType': '4'},
#    {'icon': 'https://gw.alicdn.com/imgextra/i3/O1CN01W71UiF1LeRIVqb1Ci_!!6000000001324-2-tps-45-45.png',
#     'isSupport': 'true',
#     'renderType': '1',
#     'tagDesc': '发票开具方：北京佳艺汇鑫国际文化发展有限公司\r\n本项目支持开具电子发票。该发票由主办方提供，需要在演出开始前在订单详情页提交发票申请，一般演出结束后1个月左右开具并发送至您的邮箱',
#     'tagDescWithStyle': '<b>发票开具方：北京佳艺汇鑫国际文化发展有限公司</b><br>本项目支持开具电子发票。该发票由主办方提供，需要在演出开始前在订单详情页提交发票申请，一般演出结束后1个月左右开具并发送至您的邮箱',
#     'tagName': '电子发票',
#     'tagType': '5'}]},
#  'venue': {'lat': 30.254925,
#   'lng': 120.162413,
#   'region': '1',
#   'venueAddr': '杭州市上城区平海路124号湖滨88 商城3楼',
#   'venueCityName': '杭州市',
#   'venueId': '6671014',
#   'venueName': '大笑喜剧脱口秀(西湖湖滨店)',
#   'venueProvinceName': '浙江省'},
#  'version': '2'}

# %%
params
# Out:
# {'jsv': '2.7.2',
#  'appKey': '12574478',
#  't': '1715436667082',
#  'sign': 'b21b18d54abaaf4f0bb739d8ebdbacbd',
#  'api': 'mtop.damai.item.detail.getdetail',
#  'v': '1.0',
#  'H5Request': 'true',
#  'type': 'json',
#  'timeout': '10000',
#  'dataType': 'json',
#  'valueType': 'string',
#  'forceAntiCreep': 'true',
#  'AntiCreep': 'true',
#  'useH5': 'true',
#  'data': '{"itemId":"787238251934","platform":"8","comboChannel":"2","dmChannel":"damai@damaih5_h5"}'}

# %%
r = requests.get(url, headers=headers, params=params)

# %%
r.text
# Out:
# '{"api":"mtop.damai.item.detail.getdetail","data":{"legacy":"{\\"detailViewComponentMap\\":{\\"item\\":{\\"staticData\\":{\\"itemBase\\":{\\"itemId\\":\\"787238251934\\",\\"itemName\\":\\"【长沙】2024长沙草莓音乐节\\",\\"subTitle\\":\\"\\",\\"generalAgent\\":{\\"generalAgent\\":\\"true\\",\\"description\\":\\"总票代\\",\\"generalType\\":\\"2\\"},\\"nationalStandardCityId\\":\\"430100\\",\\"cityName\\":\\"长沙市\\",\\"categoryId\\":\\"127420006\\",\\"itemPic\\":\\"https://img.alicdn.com/bao/uploaded/https://img.alicdn.com/imgextra/i2/2251059038/O1CN01ueknFT2GdSatBDEir_!!2251059038.jpg\\",\\"itemPics\\":{\\"itemPicList\\":[{\\"picUrl\\":\\"https://img.alicdn.com/imgextra/i2/2251059038/O1CN01ueknFT2GdSatBDEir_!!2251059038.jpg\\"}]},\\"showTime\\":\\"2024.06.14-06.16\\",\\"showDuration\\":\\"以现场为准\\",\\"serviceNotes\\":[{\\"isSupport\\":\\"true\\",\\"tagName\\":\\"条件退\\",\\"tagDesc\\":\\"本项目支持有条件退款，若需要收取退票手续费，将以用户实际支付票款为基准收取。基于项目主办方提供的退票政策不同，具体可支持用户申请退款的情形请详见该项目详情页退票政策相关说明或公告。\\",\\"tagType\\":\\"2\\",\\"renderType\\":\\"2\\",\\"tagDescJson\\":\\"{\\\\\\"generalNote\\\\\\":\\\\\\"该演出支持退票，您可以在【我的-订单详情页】中申请退票，退票需要收取手续费，具体规则如下；\\\\\\",\\\\\\"performRules\\\\\\":[{\\\\\\"rules\\\\\\":[{\\\\\\"endTime\\\\\\":1714194000000,\\\\\\"ruleStage\\\\\\":3,\\\\\\"ruleType\\\\\\":2,\\\\\\"startTime\\\\\\":1714107600000},{\\\\\\"endTime\\\\\\":1717477200000,\\\\\\"ruleFeeBP\\\\\\":3000,\\\\\\"ruleStage\\\\\\":2,\\\\\\"ruleType\\\\\\":1,\\\\\\"startTime\\\\\\":1714194000000},{\\\\\\"ruleStage\\\\\\":1,\\\\\\"ruleType\\\\\\":4,\\\\\\"startTime\\\\\\":1717477200000}]}],\\\\\\"refundProcedureFeeRule\\\\\\":1}\\",\\"icon\\":\\"https://gw.alicdn.com/imgextra/i3/O1CN01W71UiF1LeRIVqb1Ci_!!6000000001324-2-tps-45-45.png\\"},{\\"isSupport\\":\\"true\\",\\"tagName\\":\\"实名制购票和入场\\",\\"tagDesc\\":\\"本项目需实名制购票及入场，购票完成后观演人信息不可更改，须购票时填写的实名观演人携带本人有效证件验证入场。\\",\\"tagType\\":\\"1\\",\\"renderType\\":\\"1\\",\\"icon\\":\\"https://gw.alicdn.com/imgextra/i3/O1CN01W71UiF1LeRIVqb1Ci_!!6000000001324-2-tps-45-45.png\\"},{\\"isSupport\\":\\"true\\",\\"tagName\\":\\"快递票\\",\\"tagDesc\\":\\"快递票：纸质票会在开票后快递到您留下的收货地址，需您承担邮寄费用。该演出不支持修改收货地址，在购票时请确认收货地址填写正确。\\\\r\\\\n注：距开演时间仅3天时，不再寄送快递票，支持在指定取票地点取票（具体以下单后票夹信息为准）\\",\\"tagDescWithStyle\\":\\"快递票：纸质票会在开票后快递到您留下的收货地址，需您承担邮寄费用。<b>该演出不支持修改收货地址，在购票时请确认收货地址填写正确。</b><br/>注：距开演时间仅3天时，不再寄送快递票，支持在指定取票地点取票（具体以下单后票夹信息为准）\\",\\"tagType\\":\\"4\\",\\"renderType\\":\\"1\\",\\"icon\\":\\"https://gw.alicdn.com/imgextra/i3/O1CN01W71UiF1LeRIVqb1Ci_!!6000000001324-2-tps-45-45.png\\"},{\\"isSupport\\":\\"true\\",\\"tagName\\":\\"电子发票\\",\\"tagDesc\\":\\"发票开具方：上海摩登天空文化传播有限公司\\\\r\\\\n本项目支持开具电子发票。该发票由主办方提供，需要在演出开始前在订单详情页提交发票申请，一般演出结束后1个月左右开具并发送至您的邮箱\\",\\"tagDescWithStyle\\":\\"<b>发票开具方：上海摩登天空文化传播有限公司</b><br>本项目支持开具电子发票。该发票由主办方提供，需要在演出开始前在订单详情页提交发票申请，一般演出结束后1个月左右开具并发送至您的邮箱\\",\\"tagType\\":\\"5\\",\\"renderType\\":\\"1\\",\\"icon\\":\\"https://gw.alicdn.com/imgextra/i3/O1CN01W71UiF1LeRIVqb1Ci_!!6000000001324-2-tps-45-45.png\\"}],\\"oldCompanyId\\":\\"702\\",\\"atomSplit\\":\\"1\\",\\"isHotProject\\":\\"true\\",\\"isShowHotProjectModel\\":\\"false\\",\\"isShowGrabTicketGuide\\":\\"false\\",\\"isShowGrabTicketGuideLink\\":\\"false\\",\\"projectStatus\\":\\"1\\",\\"itemType\\":\\"1\\",\\"hasServiceFee\\":\\"false\\"},\\"itemExtendInfo\\":{\\"itemDescTitle\\":\\"演出介绍\\",\\"itemExtend\\":\\"<!DOCTYPE html><html><head></head><body><p><img src=\\\\\\"https://img.alicdn.com/imgextra/i2/2251059038/O1CN01Mcu09k2GdSavVPjsu_!!2251059038.jpg\\\\\\" width=\\\\\\"1067\\\\\\" height=\\\\\\"747\\\\\\" damai_width=\\\\\\"3557\\\\\\" damai_height=\\\\\\"2490\\\\\\"></p>\\\\n<p><img src=\\\\\\"https://img.alicdn.com/imgextra/i3/2251059038/O1CN01ciyo9F2GdSasuJnqk_!!2251059038.jpg\\\\\\" width=\\\\\\"1884\\\\\\" height=\\\\\\"2592\\\\\\" damai_width=\\\\\\"1884\\\\\\" damai_height=\\\\\\"2592\\\\\\"></p>\\\\n<p><strong>购票和入场须知/演出艺人/艺人演出时间请往下查阅</strong><br>温馨提示：购票前请务必确认好购票信息（购买场次、票种、观演人信息等），请您阅读、理解并接受须知内容后再进行门票购买、持有或使用。<br><img src=\\\\\\"https://img.alicdn.com/imgextra/i2/2251059038/O1CN010Ts ...

# %%
json_r = r.json()
json_legacy = json.loads(json_r['data']['legacy'])
json_legacy.keys()
# Out:
# dict_keys(['detailViewComponentMap'])

# %%
# save json_r to file
with open('test-detail.json', 'w') as f:
    json.dump(json_legacy, f, indent=4)

# %%
json_legacy['detailViewComponentMap']['item']['staticData'].keys()
# Out:
# dict_keys(['itemBase', 'itemExtendInfo', 'ticketNotes', 'tips', 'noticeMatter', 'realName', 'venue', 'returnPolicy', 'tourProjects', 'sharingBar', 'faqs', 'ext', 'announcementVO', 'alipayDetailUrl', 'alipayLandingPageUrl'])

# %%
# url = "https://search.damai.cn/external/gl.html"  # 推荐演出
# url = "https://detail.damai.cn/item.htm"
# url = "https://detail.damai.cn/subpage?itemId=787238251934&apiVersion=2.0&dmChannel=pc@damai_pc&bizCode=ali.china.damai&scenario=itemsku&dataType=&datald=&privilegeActld=&callback=__jp0"
# url = "https://detail.damai.cn/item.htm?spm=a2oeg.search_category.0.0.5f724d15lPEwye&id=789240991916"
# url = "https://detail.damai.cn/subpage"
# url = "https://api-gw.damai.cn/navigation.html?_ksTS=1715416331135_24&callback=jsonp25"
# url = 'https://mtop.damai.cn/h5/mtop.damai.item.detail.getdetail/1.0/?jsv=2.7.2&appKey=12574478&t=1715426122728&sign=61c0dd04778bed4ea7d64fa94447b527&api=mtop.damai.item.detail.getdetail&v=1.0&H5Request=true&type=json&timeout=10000&dataType=json&valueType=string&forceAntiCreep=true&AntiCreep=true&useH5=true&data=%7B%22itemId%22%3A%22670401840202%22%2C%22platform%22%3A%228%22%2C%22comboChannel%22%3A%222%22%2C%22dmChannel%22%3A%22damai%40damaih5_h5%22%7D'

# params = {
#     'itemId': '789240991916',
#     'apiVersion': '2.0',
#     'dmChannel': 'pc@damai_pc',
#     'bizCode': 'ali.china.damai',
#     'scenario': 'itemsku',
#     'dataType': '',
#     'datald': '',
#     'privilegeActld': '',
#     'callback': '__jp0',
# }

# %%
# params = {
#     "type": 1,
#     # "projects": 787238251934,
#     "projectId": 789240991916,
# }
# params = {
#     # "type": 1,
#     "projects": 787238251934,
#     # "id": 789240991916,
# }
params = {
    'sigh': '61c0dd04778bed4ea7d64fa94447b527',
    't': '1715426122728',
    'itemId': '789240991916',
}

# %%
# 测试一条，看是否能返回更多信息
# test_r = requests.get(url, headers=headers, params=params)
test_r = requests.get(url, headers=headers)
test_r
# test_json_r = test_r.json()
# test_json_r
# Out:
# <Response [200]>

# %%
test_r.text
# Out:
# 'jsonp25({"data":[]})'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(test_r.text, 'html.parser')
# soup
# soup.find_all(class_='perform')

# %%
test_str = u"\u53d6\u7968\u5730\u5740\u5728\u54ea\u91cc"
# unicode to utf-8
test_str.encode('utf-8')
# Out:
# b'\xe5\x8f\x96\xe7\xa5\xa8\xe5\x9c\xb0\xe5\x9d\x80\xe5\x9c\xa8\xe5\x93\xaa\xe9\x87\x8c'
